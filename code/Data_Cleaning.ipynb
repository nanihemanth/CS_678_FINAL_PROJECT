# %%
import pandas as pd
df=pd.read_csv("/content/multilingual_test.tsv",sep="\t")
df
# Out:
#                     ID                                              tweet  \
# 0      mul_test_000001  لا للفتنة لا للتخريب كلنا محسن فكري  https://y...
# 1      mul_test_000002  eyya gaskiya ya mlm falalu yakamata akara time...
# 2      mul_test_000003                             malaolu mu ala fun olu
# 3      mul_test_000004  😅😅😅 afinal existe um grupo do Twitter que fala...
# 4      mul_test_000005  Juroooo 🤣😂🤣😂🤣😂🤣 vce pode dar nariz até. Não ga...
# ...                ...                                                ...
# 30206  mul_test_030207                 na wetin suppose happen dey happen
# 30207  mul_test_030208  O que aconteceu com todas aquelas empresas MOZ...
# 30208  mul_test_030209  what occupation is old ìbàdàn known for clue i...
# 30209  mul_test_030210  '@user እንዴ ግሩም፣ አለም አቀፉ ማህበረሰብ እንደ ኦፊሴላዊ የመረጃ ...
# 30210  mul_test_030211             adepa pls settle me 0546498199 muftawu
#
#           label
# 0      positive
# 1       neutral
# 2       neutral
# 3      negative
# 4       neutral
# ...         ...
# 30206  positive
# 30207   neutral
# 30208   neutral
# 30209   neutral
# 30210  positive
#
# [30211 rows x 3 columns]

# %%
import re
import string

def clean_text(text):
    # Remove links
    text = re.sub(r'http\S+', '', text)

    # Remove mentions (e.g., @user)
    text = re.sub(r'@\S+', '', text)

    # Remove emojis
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251"
        "]+", flags=re.UNICODE)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    text = emoji_pattern.sub(r'', text)

    # Remove extra whitespaces
    text = re.sub(' +', ' ', text)
    text = re.sub(r'\d+', '', text)

    return text.strip()

# %%
df["cleaned"]=df["tweet"].apply(clean_text)

# %%
df
# Out:
#                     ID                                              tweet  \
# 0      mul_test_000001  لا للفتنة لا للتخريب كلنا محسن فكري  https://y...
# 1      mul_test_000002  eyya gaskiya ya mlm falalu yakamata akara time...
# 2      mul_test_000003                             malaolu mu ala fun olu
# 3      mul_test_000004  😅😅😅 afinal existe um grupo do Twitter que fala...
# 4      mul_test_000005  Juroooo 🤣😂🤣😂🤣😂🤣 vce pode dar nariz até. Não ga...
# ...                ...                                                ...
# 30206  mul_test_030207                 na wetin suppose happen dey happen
# 30207  mul_test_030208  O que aconteceu com todas aquelas empresas MOZ...
# 30208  mul_test_030209  what occupation is old ìbàdàn known for clue i...
# 30209  mul_test_030210  '@user እንዴ ግሩም፣ አለም አቀፉ ማህበረሰብ እንደ ኦፊሴላዊ የመረጃ ...
# 30210  mul_test_030211             adepa pls settle me 0546498199 muftawu
#
#           label                                            cleaned
# 0      positive       لا للفتنة لا للتخريب كلنا محسن فكري محسنفكري
# 1       neutral  eyya gaskiya ya mlm falalu yakamata akara time...
# 2       neutral                             malaolu mu ala fun olu
# 3      negative  afinal existe um grupo do Twitter que falam ma...
# 4       neutral    Juroooo vce pode dar nariz até Não garante nada
# ...         ...                                                ...
# 30206  positive                 na wetin suppose happen dey happen
# 30207   neutral  O que aconteceu com todas aquelas empresas MOZ...
# 30208   neutral  what occupation is old ìbàdàn known for clue i...
# 30209   neutral  እንዴ ግሩም፣ አለም አቀፉ ማህበረሰብ እንደ ኦፊሴላዊ የመረጃ ምንጭ የወሰ...
# 30210  positive                       adepa pls settle me  muftawu
#
# [30211 rows x 4 columns]

# %%
df.to_csv("mutli_clean_test.csv",index="False")
